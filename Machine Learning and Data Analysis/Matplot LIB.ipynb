# %% [markdown]
# # PARTE 1

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
x = np.linspace(0,5,11)
y = x**2

# %%
plt.plot(x,y,'r-')
plt.xlabel('X Label')
plt.title('title')
# Out:
# Text(0.5,1,'title')

# %%
#matplot retorna o grid dado para um determinado valor

plt.subplot(3,3,1)
plt.plot(x,y,'r')

plt.subplot(3,3,2)
plt.plot(y,x,'b')

# %%
#matplot retorna o grid dado para um determinado valor

plt.subplot(1,1,1)
plt.plot(x,y,'r')

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'r')

plt.subplot(2,2,2)
plt.plot(y,x,'b')

# %%
fig = plt.figure()
axes = fig.add_axes(([0.1,0.1,0.8,0.8]))
axes.plot(x,y)

axes.set_xlabel('x label')
# Out:
# Text(0.5,0,'x label')

# %%
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_xlabel('x label')
# Out:
# Text(0.5,0,'x label')

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.2])

axes1.plot(x,y)
axes2.plot(y,x)

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.5,0.5,0.4,0.3])

# %% [markdown]
# # PARTE 2

# %%
fig,axes = plt.subplots(nrows=1, ncols=2)
plt.tight_layout()

for current_ax in axes:
    current_ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(x,y)

axes[1].plot(y,x)

# %%
fig,axes = plt.subplots(nrows = 2, ncols =1,figsize =(8,2))
axes[0].plot(x,y)
axes[1].plot(y,x)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,x**2,label='aqui')
ax.plot(x,x**3,label ='X cubed')
ax.legend(loc =(0.1,0.1))

# %%
fig.savefig('my_picture.png', dpi =200)

# %% [markdown]
# # Parte 3

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,color ='green', lw =3,alpha = 0.5)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,color ='blue', lw =3, linestyle = ':', marker = 'o', markersize = 20, 
       markerfacecolor = 'black')

# %%
plt.scatter(x,y)

# %%
pwd
# Out:
# 'C:\\Users\\llucas'
